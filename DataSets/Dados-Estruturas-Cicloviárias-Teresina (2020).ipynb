# %% [markdown]
# # Dados-Estruturas-Cicloviárias-Teresina (2020)

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cthe_df = pd.read_excel("Infraestrutura cicloviária de circulação existente.xlsx")

# %%
cthe_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
# ZONA           19 non-null object
# VIA            19 non-null object
# INICIO         19 non-null object
# FIM            19 non-null object
# TIPO           19 non-null object
# TIPOLOGIA      19 non-null object
# EXTENSÃO KM    19 non-null float64
# dtypes: float64(1), object(6)
# memory usage: 1.2+ KB

# %%
cthe_df
# Out:
#        ZONA                           VIA                           INICIO  \
# 0    centro              Av. Maranhão (I)              R. Coelho Rodrigues
# 1    centro             Av. Maranhão (II)             Av. Joaquim Ribeiro
# 2    centro               Av. Miguel Rosa                 Av. Higino Cunha
# 3    centro       Av. Mal. Castelo Branco            Av. Petrônio Portella
# 4       sul    Av. Pref. Wall Ferraz (I)         R. Sen. Joaquim Paranaguá
# 5       sul    Av. Pref. Wall Ferraz (II)           R. Dezenove de Outubro
# 6       sul    Av. Henry Wall de Carvalho         Av. Pres. Getúlio Vargas
# 7       sul      Av. Pres. Getúlio Vargas       Av. Henry Wall de Carvalho
# 8     norte               R. Rui Barbosa                          R. Piauí
# 9     norte           Av. Duque de Caxias                   Av. Pernambuco
# 10    norte                Av. Jerumenha               Av. Duque de Caxias
# ...
